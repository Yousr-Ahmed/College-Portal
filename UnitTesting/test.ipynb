# %%
# !pip install selenium == 4.1.3
# !pip install Faker == 13.7.0

# %%
from time import sleep
import unittest

from selenium import webdriver
from selenium.webdriver.chrome.service import Service as ChromeService
from selenium.webdriver.common.by import By
from webdriver_manager.chrome import ChromeDriverManager
from faker import Faker

# %%
Base_url = r"http://localhost:8000/"
login_url = Base_url + r'campus_portal/Login'
signup_student = Base_url + r'campus_portal/student_signup'

# %%
faker = Faker()
time_to_sleep = .5

# %%
def generate_random_data():
    temp_password = faker.password()
    dob = faker.date_of_birth().__str__().split("-")
    dob = dob[2]+dob[1]+dob[0]
    return [faker.first_name(), faker.last_name(), faker.user_name(), faker.email(),
            temp_password, temp_password, faker.phone_number(), dob]

# %%
First_Name = "Hussein"
Last_Name = "Elwakeel"
username = "Hussein_Elwakeel"
email = "hussein_m90388@cic-cairo.com"
password = "hussein12345"  # to send the password
retyped_password = "hussein12345"  # to send the password
phone_number = "01210247381"
birthdate = "17012001"

# %%
class LoginTest(unittest.TestCase):
    def setUp(self):
        options = webdriver.ChromeOptions()
        options.headless = True

        # Start Chrome WebDriver
        self.service = ChromeService(executable_path=ChromeDriverManager(log_level=0).install())
        self.driver = webdriver.Chrome(service=self.service, options=options)
        self.driver.implicitly_wait(3)  # wait  to load the page
        self.driver.maximize_window()  # to max the window

    def test_login_by_empty_fields(self):
        self.driver.get(login_url)

        self.username_field = self.driver.find_element(By.NAME, 'email')
        self.username_field.send_keys('')

        self.password_field = self.driver.find_element(By.NAME, 'password')
        self.password_field.send_keys('')

        self.login_button = self.driver.find_element(By.XPATH, '/html/body/main/form/div[2]/div[2]/button')
        self.login_button.click()
        sleep(time_to_sleep)
        self.assertEqual(login_url, self.driver.current_url)

    def test_login_by_username(self):
        self.driver.get(login_url)

        self.username_field = self.driver.find_element(By.NAME, 'email')
        self.username_field.send_keys(username)

        self.password_field = self.driver.find_element(By.NAME, 'password')
        self.password_field.send_keys(password)

        self.remember_me = self.driver.find_element(By.NAME, 'remember_me')
        self.remember_me.click()

        self.login_button = self.driver.find_element(By.XPATH, '/html/body/main/form/div[2]/div[2]/button')
        self.login_button.click()
        sleep(time_to_sleep)
        self.assertNotEqual(login_url, self.driver.current_url)

    def test_login_by_email(self):
        self.driver.get(login_url)

        self.username_field = self.driver.find_element(By.NAME, 'email')
        self.username_field.send_keys(email)

        self.password_field = self.driver.find_element(By.NAME, 'password')
        self.password_field.send_keys(password)

        self.remember_me = self.driver.find_element(By.NAME, 'remember_me')
        self.remember_me.click()

        self.login_button = self.driver.find_element(By.XPATH, '/html/body/main/form/div[2]/div[2]/button')
        self.login_button.click()
        sleep(time_to_sleep)
        self.assertNotEqual(login_url, self.driver.current_url)

    # Edit Here
    def test_signup_without_agree_terms_field(self):
        #should start with test4
        First_Name, Last_Name, username, email, password, retyped_password, phone_number, birthdate = generate_random_data()
        self.driver.get(signup_student)

        self.first_name_field = self.driver.find_element(By.NAME, "first_name")
        self.first_name_field.send_keys(First_Name)
        self.last_name_field = self.driver.find_element(By.NAME, 'last_name')
        self.last_name_field.send_keys(Last_Name)

        self.username_field = self.driver.find_element(By.NAME, 'username')
        self.username_field.send_keys(username)

        self.email_field = self.driver.find_element(By.NAME, 'email')
        self.email_field.send_keys(email)

        self.password_field = self.driver.find_element(By.NAME, 'password')
        self.password_field.send_keys(password)

        self.retype_password_field = self.driver.find_element(By.NAME, 'retyped_password')
        self.retype_password_field.send_keys(retyped_password)

        self.phone_number_field = self.driver.find_element(By.NAME, 'phone_number')
        self.phone_number_field.send_keys(phone_number)

        self.birthdate_field = self.driver.find_element(By.NAME, 'birthdate')
        self.birthdate_field.send_keys(birthdate)

        # Check if agreeTerms_button required
        # self.agreeTerms_button = self.driver.find_element(By.ID, 'agreeTerms')
        # self.driver.execute_script("arguments[0].click();", self.agreeTerms_button)

        self.register_button = self.driver.find_element(By.XPATH, '//*[@id="form"]/div[13]/div[2]/button')
        self.driver.execute_script("arguments[0].click();", self.register_button)
        sleep(time_to_sleep)
        self.assertEqual(signup_student, self.driver.current_url)

    def test_signup_by_empty_fields(self):
        #should start with test4
        First_Name, Last_Name, username, email, password, retyped_password, phone_number, birthdate = generate_random_data()
        self.driver.get(signup_student)

        self.first_name_field = self.driver.find_element(By.NAME, "first_name")
        self.first_name_field.send_keys('')

        self.last_name_field = self.driver.find_element(By.NAME, 'last_name')
        self.last_name_field.send_keys('')

        self.username_field = self.driver.find_element(By.NAME, 'username')
        self.username_field.send_keys('')

        self.email_field = self.driver.find_element(By.NAME, 'email')
        self.email_field.send_keys('')

        self.password_field = self.driver.find_element(By.NAME, 'password')
        self.password_field.send_keys('')

        self.retype_password_field = self.driver.find_element(By.NAME, 'retyped_password')
        self.retype_password_field.send_keys('')

        self.phone_number_field = self.driver.find_element(By.NAME, 'phone_number')
        self.phone_number_field.send_keys('')

        self.birthdate_field = self.driver.find_element(By.NAME, 'birthdate')
        self.birthdate_field.send_keys('')

        self.agreeTerms_button = self.driver.find_element(By.ID, 'agreeTerms')
        self.driver.execute_script("arguments[0].click();", self.agreeTerms_button)

        self.register_button = self.driver.find_element(By.XPATH, '//*[@id="form"]/div[13]/div[2]/button')
        self.driver.execute_script("arguments[0].click();", self.register_button)
        sleep(time_to_sleep)
        self.assertEqual(signup_student, self.driver.current_url)

    def test_signup_with_one_has_register_fields(self):
        #should start with test4
        First_Name, Last_Name, username, _, password, retyped_password, phone_number, _ = generate_random_data()
        #should start with test
        birthdate = "01/01/2000"
        email = "hussein_m90388@cic-cairo.com"
        self.driver.get(signup_student)

        self.first_name_field = self.driver.find_element(By.NAME, "first_name")
        self.first_name_field.send_keys(First_Name)

        self.last_name_field = self.driver.find_element(By.NAME, 'last_name')
        self.last_name_field.send_keys(Last_Name)

        self.username_field = self.driver.find_element(By.NAME, 'username')
        self.username_field.send_keys(username)

        self.email_field = self.driver.find_element(By.NAME, 'email')
        self.email_field.send_keys(email)

        self.password_field = self.driver.find_element(By.NAME, 'password')
        self.password_field.send_keys(password)

        self.retype_password_field = self.driver.find_element(By.NAME, 'retyped_password')
        self.retype_password_field.send_keys(retyped_password)

        self.phone_number_field = self.driver.find_element(By.NAME, 'phone_number')
        self.phone_number_field.send_keys(phone_number)

        self.birthdate_field = self.driver.find_element(By.NAME, 'birthdate')
        self.birthdate_field.send_keys(birthdate)

        self.agreeTerms_button = self.driver.find_element(By.ID, 'agreeTerms')
        self.driver.execute_script("arguments[0].click();", self.agreeTerms_button)

        self.register_button = self.driver.find_element(By.XPATH, '//*[@id="form"]/div[13]/div[2]/button')
        self.driver.execute_script("arguments[0].click();", self.register_button)
        sleep(time_to_sleep)
        self.assertEqual(signup_student, self.driver.current_url)

    def test_signup_without_email_field(self):
        #should start with test4
        First_Name, Last_Name, username, email, password, retyped_password, phone_number, birthdate = generate_random_data()
        self.driver.get(signup_student)

        self.first_name_field = self.driver.find_element(By.NAME, "first_name")
        self.first_name_field.send_keys(First_Name)

        self.last_name_field = self.driver.find_element(By.NAME, 'last_name')
        self.last_name_field.send_keys(Last_Name)

        self.username_field = self.driver.find_element(By.NAME, 'username')
        self.username_field.send_keys(username)

        self.password_field = self.driver.find_element(By.NAME, 'password')
        self.password_field.send_keys(password)

        self.retype_password_field = self.driver.find_element(By.NAME, 'retyped_password')
        self.retype_password_field.send_keys(retyped_password)

        self.phone_number_field = self.driver.find_element(By.NAME, 'phone_number')
        self.phone_number_field.send_keys(phone_number)

        self.birthdate_field = self.driver.find_element(By.NAME, 'birthdate')
        self.birthdate_field.send_keys(birthdate)

        self.agreeTerms_button = self.driver.find_element(By.ID, 'agreeTerms')
        self.driver.execute_script("arguments[0].click();", self.agreeTerms_button)

        self.register_button = self.driver.find_element(By.XPATH, '//*[@id="form"]/div[13]/div[2]/button')
        self.driver.execute_script("arguments[0].click();", self.register_button)
        sleep(time_to_sleep)
        self.assertEqual(signup_student, self.driver.current_url)

    def test_signup_without_first_name_field(self):
        #should start with test4
        First_Name, Last_Name, username, email, password, retyped_password, phone_number, birthdate = generate_random_data()
        self.driver.get(signup_student)

        self.last_name_field = self.driver.find_element(By.NAME, 'last_name')
        self.last_name_field.send_keys(Last_Name)

        self.username_field = self.driver.find_element(By.NAME, 'username')
        self.username_field.send_keys(username)

        self.email_field = self.driver.find_element(By.NAME, 'email')
        self.email_field.send_keys(email)

        self.password_field = self.driver.find_element(By.NAME, 'password')
        self.password_field.send_keys(password)

        self.retype_password_field = self.driver.find_element(By.NAME, 'retyped_password')
        self.retype_password_field.send_keys(retyped_password)

        self.phone_number_field = self.driver.find_element(By.NAME, 'phone_number')
        self.phone_number_field.send_keys(phone_number)

        self.birthdate_field = self.driver.find_element(By.NAME, 'birthdate')
        self.birthdate_field.send_keys(birthdate)

        self.agreeTerms_button = self.driver.find_element(By.ID, 'agreeTerms')
        self.driver.execute_script("arguments[0].click();", self.agreeTerms_button)

        self.register_button = self.driver.find_element(By.XPATH, '//*[@id="form"]/div[13]/div[2]/button')
        self.driver.execute_script("arguments[0].click();", self.register_button)
        sleep(time_to_sleep)
        self.assertEqual(signup_student, self.driver.current_url)

    def test_signup_without_last_name_fields(self):
        #should start with test4
        First_Name, Last_Name, username, email, password, retyped_password, phone_number, birthdate = generate_random_data()
        self.driver.get(signup_student)

        self.first_name_field = self.driver.find_element(By.NAME, "first_name")
        self.first_name_field.send_keys(First_Name)

        self.username_field = self.driver.find_element(By.NAME, 'username')
        self.username_field.send_keys(username)

        self.email_field = self.driver.find_element(By.NAME, 'email')
        self.email_field.send_keys(email)

        self.password_field = self.driver.find_element(By.NAME, 'password')
        self.password_field.send_keys(password)

        self.retype_password_field = self.driver.find_element(By.NAME, 'retyped_password')
        self.retype_password_field.send_keys(retyped_password)

        self.phone_number_field = self.driver.find_element(By.NAME, 'phone_number')
        self.phone_number_field.send_keys(phone_number)

        self.birthdate_field = self.driver.find_element(By.NAME, 'birthdate')
        self.birthdate_field.send_keys(birthdate)

        self.agreeTerms_button = self.driver.find_element(By.ID, 'agreeTerms')
        self.driver.execute_script("arguments[0].click();", self.agreeTerms_button)

        self.register_button = self.driver.find_element(By.XPATH, '//*[@id="form"]/div[13]/div[2]/button')
        self.driver.execute_script("arguments[0].click();", self.register_button)
        sleep(time_to_sleep)
        self.assertEqual(signup_student, self.driver.current_url)

    def test_signup_without_username_fields(self):
        #should start with test4
        First_Name, Last_Name, username, email, password, retyped_password, phone_number, birthdate = generate_random_data()
        self.driver.get(signup_student)

        self.first_name_field = self.driver.find_element(By.NAME, "first_name")
        self.first_name_field.send_keys(First_Name)

        self.last_name_field = self.driver.find_element(By.NAME, 'last_name')
        self.last_name_field.send_keys(Last_Name)

        self.email_field = self.driver.find_element(By.NAME, 'email')
        self.email_field.send_keys(email)

        self.password_field = self.driver.find_element(By.NAME, 'password')
        self.password_field.send_keys(password)

        self.retype_password_field = self.driver.find_element(By.NAME, 'retyped_password')
        self.retype_password_field.send_keys(retyped_password)

        self.phone_number_field = self.driver.find_element(By.NAME, 'phone_number')
        self.phone_number_field.send_keys(phone_number)

        self.birthdate_field = self.driver.find_element(By.NAME, 'birthdate')
        self.birthdate_field.send_keys(birthdate)

        self.agreeTerms_button = self.driver.find_element(By.ID, 'agreeTerms')
        self.driver.execute_script("arguments[0].click();", self.agreeTerms_button)

        self.register_button = self.driver.find_element(By.XPATH, '//*[@id="form"]/div[13]/div[2]/button')
        self.driver.execute_script("arguments[0].click();", self.register_button)
        sleep(time_to_sleep)
        self.assertEqual(signup_student, self.driver.current_url)

    def test_signup_without_password_fields(self):
        #should start with test4
        First_Name, Last_Name, username, email, password, retyped_password, phone_number, birthdate = generate_random_data()
        self.driver.get(signup_student)

        self.first_name_field = self.driver.find_element(By.NAME, "first_name")
        self.first_name_field.send_keys(First_Name)

        self.last_name_field = self.driver.find_element(By.NAME, 'last_name')
        self.last_name_field.send_keys(Last_Name)

        self.username_field = self.driver.find_element(By.NAME, 'username')
        self.username_field.send_keys(username)

        self.email_field = self.driver.find_element(By.NAME, 'email')
        self.email_field.send_keys(email)

        self.retype_password_field = self.driver.find_element(By.NAME, 'retyped_password')
        self.retype_password_field.send_keys(retyped_password)

        self.phone_number_field = self.driver.find_element(By.NAME, 'phone_number')
        self.phone_number_field.send_keys(phone_number)

        self.birthdate_field = self.driver.find_element(By.NAME, 'birthdate')
        self.birthdate_field.send_keys(birthdate)

        self.agreeTerms_button = self.driver.find_element(By.ID, 'agreeTerms')
        self.driver.execute_script("arguments[0].click();", self.agreeTerms_button)

        self.register_button = self.driver.find_element(By.XPATH, '//*[@id="form"]/div[13]/div[2]/button')
        self.driver.execute_script("arguments[0].click();", self.register_button)
        sleep(time_to_sleep)
        self.assertEqual(signup_student, self.driver.current_url)

    def test_signup_without_phone_number_fields(self):
        #should start with test4
        First_Name, Last_Name, username, email, password, retyped_password, phone_number, birthdate = generate_random_data()
        self.driver.get(signup_student)

        self.first_name_field = self.driver.find_element(By.NAME, "first_name")
        self.first_name_field.send_keys(First_Name)

        self.last_name_field = self.driver.find_element(By.NAME, 'last_name')
        self.last_name_field.send_keys(Last_Name)

        self.username_field = self.driver.find_element(By.NAME, 'username')
        self.username_field.send_keys(username)

        self.email_field = self.driver.find_element(By.NAME, 'email')
        self.email_field.send_keys(email)

        self.password_field = self.driver.find_element(By.NAME, 'password')
        self.password_field.send_keys(password)

        self.retype_password_field = self.driver.find_element(By.NAME, 'retyped_password')
        self.retype_password_field.send_keys(retyped_password)

        self.birthdate_field = self.driver.find_element(By.NAME, 'birthdate')
        self.birthdate_field.send_keys(birthdate)

        self.agreeTerms_button = self.driver.find_element(By.ID, 'agreeTerms')
        self.driver.execute_script("arguments[0].click();", self.agreeTerms_button)

        self.register_button = self.driver.find_element(By.XPATH, '//*[@id="form"]/div[13]/div[2]/button')
        self.driver.execute_script("arguments[0].click();", self.register_button)
        sleep(time_to_sleep)
        self.assertEqual(signup_student, self.driver.current_url)

    def test_signup_without_birthdate_fields(self):
        #should start with test4
        First_Name, Last_Name, username, email, password, retyped_password, phone_number, birthdate = generate_random_data()
        self.driver.get(signup_student)

        self.first_name_field = self.driver.find_element(By.NAME, "first_name")
        self.first_name_field.send_keys(First_Name)

        self.last_name_field = self.driver.find_element(By.NAME, 'last_name')
        self.last_name_field.send_keys(Last_Name)

        self.username_field = self.driver.find_element(By.NAME, 'username')
        self.username_field.send_keys(username)

        self.email_field = self.driver.find_element(By.NAME, 'email')
        self.email_field.send_keys(email)

        self.password_field = self.driver.find_element(By.NAME, 'password')
        self.password_field.send_keys(password)

        self.retype_password_field = self.driver.find_element(By.NAME, 'retyped_password')
        self.retype_password_field.send_keys(retyped_password)

        self.phone_number_field = self.driver.find_element(By.NAME, 'phone_number')
        self.phone_number_field.send_keys(phone_number)

        self.agreeTerms_button = self.driver.find_element(By.ID, 'agreeTerms')
        self.driver.execute_script("arguments[0].click();", self.agreeTerms_button)

        self.register_button = self.driver.find_element(By.XPATH, '//*[@id="form"]/div[13]/div[2]/button')
        self.driver.execute_script("arguments[0].click();", self.register_button)
        sleep(time_to_sleep)
        self.assertEqual(signup_student, self.driver.current_url)

    def test_signup_without_retype_password_fields(self):
        #should start with test4
        First_Name, Last_Name, username, email, password, retyped_password, phone_number, birthdate = generate_random_data()
        self.driver.get(signup_student)

        self.first_name_field = self.driver.find_element(By.NAME, "first_name")
        self.first_name_field.send_keys(First_Name)

        self.last_name_field = self.driver.find_element(By.NAME, 'last_name')
        self.last_name_field.send_keys(Last_Name)

        self.username_field = self.driver.find_element(By.NAME, 'username')
        self.username_field.send_keys(username)

        self.email_field = self.driver.find_element(By.NAME, 'email')
        self.email_field.send_keys(email)

        self.password_field = self.driver.find_element(By.NAME, 'password')
        self.password_field.send_keys(password)

        self.phone_number_field = self.driver.find_element(By.NAME, 'phone_number')
        self.phone_number_field.send_keys(phone_number)

        self.birthdate_field = self.driver.find_element(By.NAME, 'birthdate')
        self.birthdate_field.send_keys(birthdate)

        self.agreeTerms_button = self.driver.find_element(By.ID, 'agreeTerms')
        self.driver.execute_script("arguments[0].click();", self.agreeTerms_button)

        self.register_button = self.driver.find_element(By.XPATH, '//*[@id="form"]/div[13]/div[2]/button')
        self.driver.execute_script("arguments[0].click();", self.register_button)
        sleep(time_to_sleep)
        self.assertEqual(signup_student, self.driver.current_url)

    def test_signup_with_new_email_fields(self):
        #should start with test4
        First_Name, Last_Name, username, email, password, retyped_password, phone_number, _ = generate_random_data()
        birthdate = "01/01/2000"
        self.driver.get(signup_student)

        self.first_name_field = self.driver.find_element(By.NAME, "first_name")
        self.first_name_field.send_keys(First_Name)

        self.last_name_field = self.driver.find_element(By.NAME, 'last_name')
        self.last_name_field.send_keys(Last_Name)

        self.username_field = self.driver.find_element(By.NAME, 'username')
        self.username_field.send_keys(faker.user_name())

        self.email_field = self.driver.find_element(By.NAME, 'email')
        self.email_field.send_keys(faker.email())

        self.password_field = self.driver.find_element(By.NAME, 'password')
        self.password_field.send_keys(password)

        self.retype_password_field = self.driver.find_element(By.NAME, 'retyped_password')
        self.retype_password_field.send_keys(retyped_password)

        self.phone_number_field = self.driver.find_element(By.NAME, 'phone_number')
        self.phone_number_field.send_keys(phone_number)

        self.birthdate_field = self.driver.find_element(By.NAME, 'birthdate')
        self.birthdate_field.send_keys(birthdate)

        self.agreeTerms_button = self.driver.find_element(By.ID, 'agreeTerms')
        self.driver.execute_script("arguments[0].click();", self.agreeTerms_button)

        self.register_button = self.driver.find_element(By.XPATH, '//*[@id="form"]/div[13]/div[2]/button')
        self.driver.execute_script("arguments[0].click();", self.register_button)
        sleep(time_to_sleep)
        self.assertNotEqual(signup_student, self.driver.current_url)

    def tearDown(self):
        # close the browser window
        self.driver.quit()

# %%
unittest.main(argv=['first-arg-is-ignored'], exit=False, verbosity=2)
# Out:
# test_login_by_email (__main__.LoginTest) ... ok
# test_login_by_empty_fields (__main__.LoginTest) ... ok
# test_login_by_username (__main__.LoginTest) ... ok
# test_signup_by_empty_fields (__main__.LoginTest) ... ok
# test_signup_with_new_email_fields (__main__.LoginTest) ... ok
# test_signup_with_one_has_register_fields (__main__.LoginTest) ... ok
# test_signup_without_agree_terms_field (__main__.LoginTest) ... ok
# test_signup_without_birthdate_fields (__main__.LoginTest) ... ok
# test_signup_without_email_field (__main__.LoginTest) ... ok
# test_signup_without_first_name_field (__main__.LoginTest) ... ok
# test_signup_without_last_name_fields (__main__.LoginTest) ... ok
# test_signup_without_password_fields (__main__.LoginTest) ... ok
# test_signup_without_phone_number_fields (__main__.LoginTest) ... ok
# test_signup_without_retype_password_fields (__main__.LoginTest) ... ok
# test_signup_without_username_fields (__main__.LoginTest) ... ok
#
# ...
